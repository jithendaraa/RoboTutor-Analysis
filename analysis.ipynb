# %%
import pandas as pd
import os

# %%
# os.chdir('Data')
# !ls
# Out:
# Transactions_Village114

# %%
# !ls
path = 'Transactions_Village114/ds3170_tx_All_Data_5208_2019_1211_082948.txt'
df = pd.read_csv(path, sep="\t")
print(df.columns)
cols = ['Anon Student Id', 
        'Session Id', 
        'Duration (sec)', 
        'Level (Tutor Name)', 
        'Level (Tutor)', 
        'Problem Name', 
        'Problem View',
        'Step Name', 
        'Attempt At Step',
        'Is Last Attempt',
        'Outcome', 
        'Input',
        'CF (File)',
        'CF (Matrix)',
        'CF (Matrix Level)', 
        'CF (Matrix Order)', 
        'CF (Total Activity Problems)'
       ]
df = df[cols]
df
# Out:
# Transactions_Village114
# C:\Users\jithe\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3,7,37,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['Row', 'Sample Name', 'Transaction Id', 'Anon Student Id', 'Session Id',
#        'Time', 'Time Zone', 'Duration (sec)', 'Student Response Type',
#        'Student Response Subtype', 'Tutor Response Type',
#        'Tutor Response Subtype', 'Level (Tutor Name)', 'Level (Tutor)',
#        'Problem Name', 'Problem View', 'Problem Start Time', 'Step Name',
#        'Attempt At Step', 'Is Last Attempt', 'Outcome', 'Selection', 'Action',
#        'Input', 'Feedback Text', 'Feedback Classification', 'Help Level',
#        'Total Num Hints', 'KC (Single-KC)', 'KC Category (Single-KC)',
#        'KC (Unique-step)', 'KC Category (Unique-step)', 'School', 'Class',
#        'CF (Activity Finished)', 'CF (Activity Started)',
#        'CF (Attempt Number)', 'CF (Child Id)', 'CF (Date)',
#        'CF (Duration sec)', 'CF (Expected Answer)', 'CF (File)',
#        'CF (Hiatus sec)', 'CF (Matrix)', 'CF (Matrix Level)',
#        'CF (Matrix Order)', 'CF (Original DS Export File)',
#        'CF (Original Order)', 'CF (Outcome Numeric)',
#        'CF (Placement Test Flag)', 'CF (Placement Test User)',
#        'CF (Problem Number)', 'CF (Robotutor Mode)', 'CF (Session Sequence)',
#        'CF (Student Chose Repeat)', 'CF (Student Used Scaffold)',
#        'CF (Total Activity Problems)', 'CF (Tutor Sequence Session)',
#        'CF (Tutor Sequence User)', 'CF (Unix Epoch)', 'CF (Village)',
#        'CF (Week)', 'Event Type'],
#       dtype='object')
#        Anon Student Id                         Session Id Duration (sec)  \
# 0           5A22000679         5A22000679_20180605_154801              0
# 1           5A22000679         5A22000679_20180605_154801              .
# 2           5A22000679         5A22000679_20180605_154801            122
# 3           5A22000679         5A22000679_20180605_154801             66
# 4           5A22000679         5A22000679_20180605_154801             97
# ...                ...                                ...            ...
# 166942      6118003535  6118003535_000081_20000114_024944             33
# 166943      6118003535  6118003535_000081_20000114_024944             13
# 166944      6118003535  6118003535_000081_20000114_024944             11
# 166945      6118003535  6118003535_000081_20000114_024944             14
# 166946      6118003535  6118003535_000081_20000114_024944             16
#
#        Level (Tutor Name)                                Level (Tutor)  \
# 0              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 1              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 2              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 3              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 4              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# ...                   ...                                          ...
# 166942          word_copy                 write.ltr.lc_all.asc.A..Z.11
# 166943          word_copy                 write.ltr.lc_all.asc.A..Z.11
# 166944          word_copy                 write.ltr.lc_all.asc.A..Z.11
# 166945          word_copy                 write.ltr.lc_all.asc.A..Z.11
# 166946          word_copy                 write.ltr.lc_all.asc.A..Z.11
#
#         Problem Name  Problem View  Step Name  Attempt At Step  \
# 0       BPOP_0_1-0-5           1.0          1                1
# 1       BPOP_0_1-0-5           1.0          1                2
# 2       BPOP_1_2-8-1           1.0          1                1
# 3       BPOP_1_2-8-1           1.0          1                2
# 4       BPOP_1_2-8-1           1.0          1                3
# ...              ...           ...        ...              ...
# 166942       write_h           1.0          1                1
# 166943       write_i           1.0          1                1
# 166944       write_j           1.0          1                1
# 166945       write_j           1.0          1                2
# 166946       write_k           1.0          1                1
#
#         Is Last Attempt    Outcome Input  \
# 0                     0  INCORRECT     1
# 1                     1    CORRECT     0
# 2                     0  INCORRECT     8
# 3                     0  INCORRECT     2
# 4                     1  INCORRECT     8
# ...                 ...        ...   ...
# 166942                1    CORRECT     h
# 166943                1    CORRECT     i
# 166944                0  INCORRECT     j
# 166945                1    CORRECT     j
# 166946                1  INCORRECT     5
#
#                                                 CF (File) CF (Matrix)  \
# 0       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 1       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 2       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 3       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 4       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# ...                                                   ...         ...
# 166942  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
# 166943  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
# 166944  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
# 166945  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
# 166946  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
#
#         CF (Matrix Level)  CF (Matrix Order)  CF (Total Activity Problems)
# 0                       1                 30                            10
# 1                       1                 30                            10
# 2                       1                 30                            10
# 3                       1                 30                            10
# 4                       1                 30                            10
# ...                   ...                ...                           ...
# 166942                  4                594                            24
# 166943                  4                594                            24
# 166944                  4                594                            24
# 166945                  4                594                            24
# 166946                  4                594                            24
#
# [166947 rows x 17 columns]

# %%
unique_student_ids = df['Anon Student Id'].unique()
no_of_students = len(unique_student_ids)
print(no_of_students)
# 16

unique_problem_names = df['Problem Name'].unique()
no_of_problem_names = len(unique_problem_names)
print(no_of_problem_names)
# 8395

unique_tutor_names = df['Level (Tutor Name)'].unique()
no_of_tutor_names = len(unique_tutor_names)
print(unique_tutor_names)
print(no_of_tutor_names) # 10
# Out:
# 16
# 8395
# ['bubble_pop' 'story_reading' 'akira' 'word_copy' 'story_questions'
#  'countingx' 'spelling' 'add_subtract' 'numdiscr' 'picmatch']
# 10

# %% [markdown]
# ## Activity-wise Analysis
# #### 'bubble_pop', 'story_reading', 'akira', 'word_copy', 'story_questions', 'countingx', 'spelling', 'add_subtract', 'numdiscr', 'picmatch'

# %%
# bubble_pop -> 23443
bubble_pop_df = df[df['Level (Tutor Name)'] == 'bubble_pop']
# bubble_pop_df

# %%
# story_reading -> 129383
story_reading_df = df[df['Level (Tutor Name)'] == 'story_reading']
# story_reading_df.count()

# %%
# akira -> 3840
akira_df = df[df['Level (Tutor Name)'] == 'akira']
# akira_df.count()

# %%
# word_copy -> 4245
word_copy_df = df[df['Level (Tutor Name)'] == 'word_copy']
# word_copy_df.count()

# %%
# story_questions -> 1142
story_questions_df = df[df['Level (Tutor Name)'] == 'story_questions']
# story_questions_df.count()

# %%
# countingx -> 471
countingx_df = df[df['Level (Tutor Name)'] == 'countingx']
# countingx_df.count()

# %%
# spelling -> 2627
spelling_df = df[df['Level (Tutor Name)'] == 'spelling']
# spelling_df.count()

# %%
# add_subtract -> 215
add_subtract_df = df[df['Level (Tutor Name)'] == 'add_subtract']
# add_subtract_df.count()

# %%
# numdiscr -> 970
numdiscr_df = df[df['Level (Tutor Name)'] == 'numdiscr']
# numdiscr_df.count()

# %%
# picmatch -> 611
picmatch_df = df[df['Level (Tutor Name)'] == 'picmatch']
# picmatch_df.count()

# %% [markdown]
# ## Bubble pop Analysis

# %%
unique_bpop_problem_names = bubble_pop_df['Problem Name'].unique()
no_of_bpop_problem_names = len(unique_bpop_problem_names)
# print(no_of_bpop_problem_names) # 3688

unique_bpop_student_ids = bubble_pop_df['Anon Student Id'].unique()
no_of_bpop_students = len(unique_bpop_student_ids)
# print(no_of_bpop_students) # 16

bpop_math_df = bubble_pop_df[bubble_pop_df['CF (Matrix)'] == 'math'] #6172
bpop_literacy_df = bubble_pop_df[bubble_pop_df['CF (Matrix)'] == 'literacy'] #17271

bpop_math_students = bpop_math_df['Anon Student Id'].unique()
bpop_literacy_students = bpop_literacy_df['Anon Student Id'].unique()

print('bpop math students: ', len(bpop_math_students))
print('bpop literacy students: ', len(bpop_literacy_students))

common = []
uniq = []
for id in unique_bpop_student_ids:
    if id in bpop_math_students and id in bpop_literacy_students:
        common.append(id)
    elif id in bpop_math_students or id in bpop_literacy_students:
        uniq.append(id)

print(len(common), len(uniq))
bubble_pop_df
# Out:
# bpop math students:  13
# bpop literacy students:  15
# 12 4
#        Anon Student Id                         Session Id Duration (sec)  \
# 0           5A22000679         5A22000679_20180605_154801              0
# 1           5A22000679         5A22000679_20180605_154801              .
# 2           5A22000679         5A22000679_20180605_154801            122
# 3           5A22000679         5A22000679_20180605_154801             66
# 4           5A22000679         5A22000679_20180605_154801             97
# ...                ...                                ...            ...
# 166924      6118003535  6118003535_000081_20000114_024944              7
# 166925      6118003535  6118003535_000081_20000114_024944             19
# 166926      6118003535  6118003535_000081_20000114_024944              3
# 166927      6118003535  6118003535_000081_20000114_024944              4
# 166928      6118003535  6118003535_000081_20000114_024944              3
#
#        Level (Tutor Name)                                      Level (Tutor)  \
# 0              bubble_pop        bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 1              bubble_pop        bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 2              bubble_pop        bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 3              bubble_pop        bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 4              bubble_pop        bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# ...                   ...                                                ...
# 166924         bubble_pop  bpop.ltr.lc_A..Z.all.asc.all.stat.show.126__it_24
# 166925         bubble_pop  bpop.ltr.lc_A..Z.all.asc.all.stat.show.126__it_24
# 166926         bubble_pop  bpop.ltr.lc_A..Z.all.asc.all.stat.show.126__it_24
# 166927         bubble_pop  bpop.ltr.lc_A..Z.all.asc.all.stat.show.126__it_24
# 166928         bubble_pop  bpop.ltr.lc_A..Z.all.asc.all.stat.show.126__it_24
#
#         Problem Name  Problem View  Step Name  Attempt At Step  \
# 0       BPOP_0_1-0-5           1.0          1                1
# 1       BPOP_0_1-0-5           1.0          1                2
# 2       BPOP_1_2-8-1           1.0          1                1
# 3       BPOP_1_2-8-1           1.0          1                2
# 4       BPOP_1_2-8-1           1.0          1                3
# ...              ...           ...        ...              ...
# 166924  BPOP_u_u-i-h           1.0          1                2
# 166925  BPOP_v_v-i-k           1.0          1                1
# 166926  BPOP_w_d-w-m           1.0          1                1
# 166927  BPOP_y_n-y-f           1.0          1                1
# 166928  BPOP_z_z-j-h           1.0          1                1
#
#         Is Last Attempt    Outcome Input  \
# 0                     0  INCORRECT     1
# 1                     1    CORRECT     0
# 2                     0  INCORRECT     8
# 3                     0  INCORRECT     2
# 4                     1  INCORRECT     8
# ...                 ...        ...   ...
# 166924                1    CORRECT     u
# 166925                1    CORRECT     v
# 166926                1    CORRECT     w
# 166927                1    CORRECT     y
# 166928                1    CORRECT     z
#
#                                                 CF (File) CF (Matrix)  \
# 0       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 1       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 2       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 3       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 4       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# ...                                                   ...         ...
# 166924  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
# 166925  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
# 166926  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
# 166927  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
# 166928  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
#
#         CF (Matrix Level)  CF (Matrix Order)  CF (Total Activity Problems)
# 0                       1                 30                            10
# 1                       1                 30                            10
# 2                       1                 30                            10
# 3                       1                 30                            10
# 4                       1                 30                            10
# ...                   ...                ...                           ...
# 166924                  4                590                            24
# 166925                  4                590                            24
# 166926                  4                590                            24
# 166927                  4                590                            24
# 166928                  4                590                            24
#
# [23443 rows x 17 columns]

# %% [markdown]
# ### bubble_pop with CF(Matrix) -> math analysis

# %%
uniq_bpop_math_level_tutor = bpop_math_df['Level (Tutor)'].unique()
no_of_bpop_math_level_tutor = len(uniq_bpop_math_level_tutor)
print("Types of 'Level (Tutor)': ", no_of_bpop_math_level_tutor)

bpop_math_problem_names = bpop_math_df['Problem Name'].unique()
no_of_bpop_math_prob_names = len(bpop_math_problem_names)
print("Problem names: ", no_of_bpop_math_prob_names)
bpop_math_df
# Out:
# Types of 'Level (Tutor)':  85
# Problem names:  1197
#        Anon Student Id                         Session Id Duration (sec)  \
# 0           5A22000679         5A22000679_20180605_154801              0
# 1           5A22000679         5A22000679_20180605_154801              .
# 2           5A22000679         5A22000679_20180605_154801            122
# 3           5A22000679         5A22000679_20180605_154801             66
# 4           5A22000679         5A22000679_20180605_154801             97
# ...                ...                                ...            ...
# 166060      6118003535  6118003535_000071_20000113_081212              6
# 166061      6118003535  6118003535_000071_20000113_081212              9
# 166062      6118003535  6118003535_000071_20000113_081212             12
# 166063      6118003535  6118003535_000071_20000113_081212             12
# 166064      6118003535  6118003535_000071_20000113_081212              8
#
#        Level (Tutor Name)                                Level (Tutor)  \
# 0              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 1              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 2              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 3              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 4              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# ...                   ...                                          ...
# 166060         bubble_pop       bpop.mn_4..9.MN-SD-UP-OFF1-BL2.decr.19
# 166061         bubble_pop       bpop.mn_4..9.MN-SD-UP-OFF1-BL2.decr.19
# 166062         bubble_pop       bpop.mn_4..9.MN-SD-UP-OFF1-BL2.decr.19
# 166063         bubble_pop       bpop.mn_4..9.MN-SD-UP-OFF1-BL2.decr.19
# 166064         bubble_pop       bpop.mn_4..9.MN-SD-UP-OFF1-BL2.decr.19
#
#             Problem Name  Problem View  Step Name  Attempt At Step  \
# 0           BPOP_0_1-0-5           1.0          1                1
# 1           BPOP_0_1-0-5           1.0          1                2
# 2           BPOP_1_2-8-1           1.0          1                1
# 3           BPOP_1_2-8-1           1.0          1                2
# 4           BPOP_1_2-8-1           1.0          1                3
# ...                  ...           ...        ...              ...
# 166060     BPOP_9_9-12-7           1.0          1                1
# 166061     BPOP_9_9-10-7           1.0          1                1
# 166062     BPOP_9_9-10-7           1.0          1                2
# 166063     BPOP_9_9-10-7           1.0          1                3
# 166064  BPOP_10_10-11-14           2.0          1                1
#
#         Is Last Attempt    Outcome Input  \
# 0                     0  INCORRECT     1
# 1                     1    CORRECT     0
# 2                     0  INCORRECT     8
# 3                     0  INCORRECT     2
# 4                     1  INCORRECT     8
# ...                 ...        ...   ...
# 166060                1    CORRECT     9
# 166061                0  INCORRECT    10
# 166062                0  INCORRECT    10
# 166063                1    CORRECT     9
# 166064                1    CORRECT    10
#
#                                                 CF (File) CF (Matrix)  \
# 0       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 1       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 2       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 3       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 4       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# ...                                                   ...         ...
# 166060  PERF_RoboTutor_release_sw_2.7.7.1_000071_2000....        math
# 166061  PERF_RoboTutor_release_sw_2.7.7.1_000071_2000....        math
# 166062  PERF_RoboTutor_release_sw_2.7.7.1_000071_2000....        math
# 166063  PERF_RoboTutor_release_sw_2.7.7.1_000071_2000....        math
# 166064  PERF_RoboTutor_release_sw_2.7.7.1_000071_2000....        math
#
#         CF (Matrix Level)  CF (Matrix Order)  CF (Total Activity Problems)
# 0                       1                 30                            10
# 1                       1                 30                            10
# 2                       1                 30                            10
# 3                       1                 30                            10
# 4                       1                 30                            10
# ...                   ...                ...                           ...
# 166060                  4                112                            10
# 166061                  4                112                            10
# 166062                  4                112                            10
# 166063                  4                112                            10
# 166064                  4                112                            10
#
# [6172 rows x 17 columns]

# %%
bpop_math_student_df = 0
cnt = 0
flag = 1
arr = []
keys = []
key_value = []

for student_id in bpop_math_students: # 13
    keys.append(student_id)
    bpop_math_student_df = bpop_math_df[bpop_math_df['Anon Student Id'] == student_id]
#     print(bpop_math_student_df)
    cols = ['Anon Student Id', 'Level (Tutor)', 'Outcome']
    bpop_math_student_df = bpop_math_student_df[cols]
    bpop_math_level_tutor = bpop_math_student_df['Level (Tutor)'].unique()
    print("Types of tutor levels assoc. with this student", student_id, ": ", len(bpop_math_level_tutor))
    arr = []
    for tutor_level in bpop_math_level_tutor:
        student_df = bpop_math_student_df[bpop_math_student_df['Level (Tutor)'] == tutor_level]

        num_correct = student_df[student_df['Outcome'] == 'CORRECT'].count()['Anon Student Id']
        num_incorrect = student_df[student_df['Outcome'] == 'INCORRECT'].count()['Anon Student Id']
        num_attempts = num_correct + num_incorrect
        percent_correct = 100*num_correct/num_attempts
        
        subarr = [student_id, tutor_level, num_correct, num_attempts, percent_correct]
        arr.append(subarr)
        print(student_id, tutor_level, num_correct, num_attempts, percent_correct)
    
    print(arr)
    student_df = pd.DataFrame(arr, columns = ['Anon Student Id', 'Level (Tutor)', '# Correct', '# attempted', '% correct'])
#     print(student_df)
    key_value_pair = (student_id, student_df) 
    key_value.append(key_value_pair)
# Out:
# Types of tutor levels assoc. with this student 5A22000679 :  1
# 5A22000679 bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2 2 7 28.571428571428573
# [['5A22000679', 'bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2', 2, 7, 28.571428571428573]]
# Types of tutor levels assoc. with this student 5A27002160 :  28
# 5A27002160 bpop.mn_40..99.MN-DD-UP-OFF5-BL4.decr.57 65 76 85.52631578947368
# 5A27002160 bpop.mn_10..99.MN-DD-UP-OFF5-BL2.incr.43 83 110 75.45454545454545
# 5A27002160 bpop.mn_10..99.MN-DD-UP-OFF10-BL4.incr.45 10 14 71.42857142857143
# 5A27002160 bpop.mn_40..99.MN-DD-UP-OFF5-BL3.decr.58 5 12 41.666666666666664
# 5A27002160 bpop.mn_10..99.MN-DD-UP-OFF5-BL1.incr.44 30 63 47.61904761904762
# 5A27002160 bpop.mn_10..99.MN-DD-UP-OFF2-BL3.incr.38 51 62 82.25806451612904
# 5A27002160 bpop.mn_10..99.MN-DD-UP-OFF2-BL2.incr.39 106 141 75.177304964539
# 5A27002160 bpop.mn_40..99.MN-DD-UP-OFF2-BL3.decr.54 94 131 71.7557251908397
# 5A27002160 bpop.mn_40..99.MN-DD-UP-OFF2-BL4.decr.53 55 86 63.95348837209303
# 5A27002160 bpop.mn_10..99.MN-DD-UP-OFF2-BL4.incr.37 79 120 65.83333333333333
# 5A27002160 bpop.mn_10..99.MN-DD-UP-OFF2-BL1.incr.40 38 90 42.22222222222222
# 5A27002160 bpop.mn_40..99.MN-DD-UP-OFF2-BL2.decr.55 9 20 45.0
# 5A27002160 bpop.mn_10..99.MN-DD-UP-OFF5-BL4.incr.41 10 11 90.9090909090909
# 5A27002160 bpop.mn_10..99.MN-DD-UP-OFF5-BL3.incr.42 38 49 77.55102040816327
# 5A27002160 bpop.mn_40..99.MN-DD-UP-OFF5-BL1.decr.60 16 20 80.0
# 5A27002160 bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2 19 20 95.0
# 5A27002160 bpop.num_0..9.by.1.rand.x2s.Ax.rise.42__it_2 10 10 100.0
# 5A27002160 bpop.gl_num.0..9.GL_SD_OFFW1_L.bub3.16 14 17 82.3529411764706
# 5A27002160 bpop.mn_4..9.MN-SD-UP-OFF10-BL1.decr.32 10 10 100.0
# 5A27002160 bpop.addsub_0..8.rand.ADD-1D-H.21 10 10 100.0
# 5A27002160 bpop.addsub_0..8.rand.SUB-1D-H.24 10 10 100.0
# 5A27002160 bpop.num_10..100.by.within.rand.x2s.Ax.rise.66__it_2 15 15 100.0
# 5A27002160 bpop.gl_num.10..99.GL_DD_OFFW10_L.bub3.28 10 10 100.0
# 5A27002160 bpop.mn_40..99.MN-DD-UP-OFF10-BL1.decr.64 9 14 64.28571428571429
# 5A27002160 bpop.mn_10..99.MN-DD-UP-OFF1-BL3.incr.34 60 71 84.50704225352112
# 5A27002160 bpop.mn_10..99.MN-DD-UP-OFF1-BL1.incr.36 32 40 80.0
# Types of tutor levels assoc. with this student 5B12002727 :  28
# 5B12002727 bpop.mn_0..9.MN-SD-UP-OFF2-BL4.incr.5 10 10 100.0
# 5B12002727 bpop.mn_0..9.MN-SD-UP-OFF2-BL3.incr.6 10 12 83.33333333333333
# 5B12002727 bpop.mn_0..9.MN-SD-UP-OFF2-BL2.incr.7 10 13 76.92307692307692
# 5B12002727 bpop.mn_0..9.MN-SD-UP-OFF5-BL3.incr.10 1 2 50.0
# 5B12002727 bpop.mn_0..9.MN-SD-UP-OFF5-BL2.incr.11 5 7 71.42857142857143
# 5B12002727 bpop.mn_0..9.MN-SD-UP-OFF5-BL1.incr.12 18 24 75.0
# 5B12002727 bpop.mn_4..9.MN-SD-UP-OFF5-BL4.decr.25 4 4 100.0
# 5B12002727 bpop.mn_4..9.MN-SD-UP-OFF5-BL2.decr.27 3 4 75.0
# 5B12002727 bpop.mn_0..9.MN-SD-UP-OFF10-BL4.incr.13 15 15 100.0
# 5B12002727 bpop.mn_4..9.MN-SD-UP-OFF10-BL3.decr.30 10 11 90.9090909090909
# 5B12002727 bpop.addsub_0..8.incr.ADD-1-V.1 9 9 100.0
# 5B12002727 bpop.addsub_0..8.rand.ADD-1D-V.2__it_1 1 2 50.0
# 5B12002727 bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2 20 22 90.9090909090909
# 5B12002727 bpop.num_1..4.by.1.asc.q2q.AV.mc.1 4 6 66.66666666666667
# 5B12002727 bpop.num_1..4.by.1.asc.q2q.AV.rise.2 10 10 100.0
# 5B12002727 bpop.num_0..9.by.1.rand.q2q.AV.mc.31 10 10 100.0
# 5B12002727 bpop.num_0..9.by.1.rand.q2q.AV.rise.32 10 10 100.0
# 5B12002727 bpop.num_0..9.by.1.asc.s2q.AV.rise.16 10 10 100.0
# 5B12002727 bpop.num_0..9.by.1.rand.s2q.AV.mc.35 10 11 90.9090909090909
# 5B12002727 bpop.num_0..9.by.1.rand.s2q.AV.rise.36 20 20 100.0
# 5B12002727 bpop.gl_num.0..9.GL_SD_OFF1_M.bub3.13 10 11 90.9090909090909
# 5B12002727 bpop.gl_num.0..9.GL_SD_OFFW1_M.bub3.15 10 11 90.9090909090909
# 5B12002727 bpop.mn_4..9.MN-SD-UP-OFF1-BL3.decr.18 60 73 82.1917808219178
# 5B12002727 bpop.mn_0..9.MN-SD-UP-OFF1-BL2.incr.3 20 23 86.95652173913044
# 5B12002727 bpop.mn_4..9.MN-SD-UP-OFF1-BL4.decr.17 12 17 70.58823529411765
# 5B12002727 bpop.mn_0..9.MN-SD-UP-OFF1-BL1.incr.4 40 50 80.0
# 5B12002727 bpop.mn_4..9.MN-SD-UP-OFF1-BL1.decr.20 10 10 100.0
# 5B12002727 bpop.mn_4..9.MN-SD-UP-OFF1-BL2.decr.19 42 51 82.3529411764706
# [['5B12002727', 'bpop.mn_0..9.MN-SD-UP-OFF2-BL4.incr.5', 10, 10, 100.0], ['5B12002727', 'bpop.mn_0..9.MN-SD-UP-OFF2-BL3.incr.6', 10, 12, 83.33333333333333], ['5B12002727', 'bpop.mn_0..9.MN-SD-UP-OFF2-BL2.incr.7', 10, 13, 76.92307692307692], ['5B12002727', 'bpop.mn_0..9.MN-SD-UP-OFF5-BL3.incr.10', 1, 2, 50.0], ['5B12002727', 'bpop.mn_0..9.MN-SD-UP-OFF5-BL2.incr.11', 5, 7, 71.42857142857143], ['5B12002727', 'bpop.mn_0..9.MN-SD-UP-OFF5-BL1.incr.12', 18, 24, 75.0], ['5B12002727', 'bpop.mn_4..9.MN-SD-UP-OFF5-BL4.decr.25', 4, 4, 100.0], ['5B12002727', 'bpop.mn_4..9.MN-SD-UP-OFF5-BL2.decr.27', 3, 4, 75.0], ['5B12002727', 'bpop.mn_0..9.MN-SD-UP-OFF10-BL4.incr.13', 15, 15, 100.0], ['5B12002727', 'bpop.mn_4..9.MN-SD-UP-OFF10-BL3.decr.30', 10, 11, 90.9090909090909], ['5B12002727', 'bpop.addsub_0..8.incr.ADD-1-V.1', 9, 9, 100.0], ['5B12002727', 'bpop.addsub_0..8.rand.ADD-1D-V.2__it_1', 1, 2, 50.0], ['5B12002727', 'bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2', 20, 22, 90.9090909090909], ['5B12002727', 'bpop.num_1..4.by.1.asc.q2q.AV.mc.1', 4, 6, 66.66666666666667], ['5B12002727', 'bpop.num_1..4.by.1.asc.q2q.AV.rise.2', 10, 10, 100.0], ['5B12002727', 'bpop.num_0..9.by.1.rand.q2q.AV.mc.31', 10, 10, 100.0], ['5B12002727', 'bpop.num_0..9.by.1.rand.q2q.AV.rise.32', 10, 10, 100.0], ['5B12002727', 'bpop.num_0..9.by.1.asc.s2q.AV.rise.16', 10, 10, 100.0], ['5B12002727', 'bpop.num_0..9.by.1.rand.s2q.AV.mc.35', 10, 11, 90.9090909090909], ['5B12002727', 'bpop.num_0..9.by.1.rand.s2q.AV.rise.36', 20, 20, 100.0], ['5B12002727', 'bpop.gl_num.0..9.GL_SD_OFF1_M.bub3.13', 10, 11, 90.9090909090909], ['5B12002727', 'bpop.gl_num.0..9.GL_SD_OFFW1_M.bub3.15', 10, 11, 90.9090909090909], ['5B12002727', 'bpop.mn_4..9.MN-SD-UP-OFF1-BL3.decr.18', 60, 73, 82.1917808219178], ['5B12002727', 'bpop.mn_0..9.MN-SD-UP-OFF1-BL2.incr.3', 20, 23, 86.95652173913044], ['5B12002727', 'bpop.mn_4..9.MN-SD-UP-OFF1-BL4.decr.17', 12, 17, 70.58823529411765], ['5B12002727', 'bpop.mn_0..9.MN-SD-UP-OFF1-BL1.incr.4', 40, 50, 80.0], ['5B12002727', 'bpop.mn_4..9.MN-SD-UP-OFF1-BL1.decr.20', 10, 10, 100.0], ['5B12002727', 'bpop.mn_4..9.MN-SD-UP-OFF1-BL2.decr.19', 42, 51, 82.3529411764706]]
# Types of tutor levels assoc. with this student 6111001777 :  10
# 6111001777 bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2 10 11 90.9090909090909
# 6111001777 bpop.num_0..9.by.1.rand.x2s.Ax.rise.42__it_2 10 11 90.9090909090909
# 6111001777 bpop.gl_num.0..9.GL_SD_OFFW1_L.bub3.16 10 11 90.9090909090909
# 6111001777 bpop.mn_4..9.MN-SD-UP-OFF10-BL1.decr.32 10 12 83.33333333333333
# 6111001777 bpop.mn_0..9.MN-SD-UP-OFF1-BL4.incr.1 20 36 55.55555555555556
# 6111001777 bpop.mn_0..9.MN-SD-UP-OFF1-BL3.incr.2 51 102 50.0
# 6111001777 bpop.mn_0..9.MN-SD-UP-OFF2-BL2.incr.7 26 40 65.0
# 6111001777 bpop.mn_0..9.MN-SD-UP-OFF2-BL1.incr.8 14 32 43.75
# 6111001777 bpop.mn_0..9.MN-SD-UP-OFF2-BL3.incr.6 10 17 58.8235294117647
# 6111001777 bpop.mn_0..9.MN-SD-UP-OFF2-BL4.incr.5 10 11 90.9090909090909
# [['6111001777', 'bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_
pop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2 20 22 90.9090909090909
# 6118002520 bpop.num_1..4.by.1.asc.q2q.AV.mc.1 12 15 80.0
# 6118002520 bpop.num_1..4.by.1.asc.q2q.AV.rise.2 10 11 90.9090909090909
# 6118002520 bpop.num_0..9.by.1.asc.q2q.AV.mc.11 10 10 100.0
# 6118002520 bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_1 10 11 90.9090909090909
# 6118002520 bpop.num_0..9.by.1.dn.q2q.AV.rise.22 10 11 90.9090909090909
# 6118002520 bpop.num_0..9.by.1.rand.q2q.AV.mc.31 12 14 85.71428571428571
# 6118002520 bpop.num_0..9.by.1.rand.q2q.AV.rise.32 11 16 68.75
# 6118002520 bpop.num_1..4.by.1.asc.s2s.AV.mc.7 15 19 78.94736842105263
# 6118002520 bpop.num_1..4.by.1.asc.s2s.AV.rise.8 10 11 90.9090909090909
# 6118002520 bpop.num_1..4.by.1.asc.x2s.Ax.mc.9 10 10 100.0
# 6118002520 bpop.num_0..9.by.1.asc.s2s.AV.mc.17 10 11 90.9090909090909
# 6118002520 bpop.num_0..9.by.1.asc.x2s.Ax.mc.19 10 11 90.9090909090909
# 6118002520 bpop.num_0..9.by.1.dn.s2s.AV.mc.27 10 10 100.0
# 6118002520 bpop.num_0..9.by.1.dn.x2s.Ax.mc.29 20 24 83.33333333333333
# 6118002520 bpop.num_0..9.by.1.dn.x2s.Ax.rise.30 24 33 72.72727272727273
# 6118002520 bpop.num_0..9.by.1.rand.s2s.AV.mc.37 10 10 100.0
# 6118002520 bpop.num_0..9.by.1.rand.s2s.AV.rise.38 10 12 83.33333333333333
# 6118002520 bpop.num_0..9.by.1.rand.x2s.Ax.mc.39 10 10 100.0
# 6118002520 bpop.num_0..9.by.1.rand.x2s.Ax.rise.42__it_1 10 13 76.92307692307692
# 6118002520 bpop.num_1..4.by.1.asc.q2s.AV.rise.4 15 22 68.18181818181819
# 6118002520 bpop.num_0..9.by.1.asc.q2s.AV.mc.13 10 10 100.0
# 6118002520 bpop.num_0..9.by.1.dn.q2s.AV.rise.24 10 10 100.0
# 6118002520 bpop.num_0..9.by.1.rand.q2s.AV.mc.33 10 10 100.0
# 6118002520 bpop.num_1..4.by.1.asc.s2q.AV.mc.5 20 21 95.23809523809524
# 6118002520 bpop.num_0..9.by.1.asc.s2q.AV.rise.16 10 12 83.33333333333333
# 6118002520 bpop.num_0..9.by.1.dn.s2q.AV.mc.25 10 12 83.33333333333333
# 6118002520 bpop.num_0..9.by.1.dn.s2q.AV.rise.26 19 30 63.333333333333336
# 6118002520 bpop.num_0..9.by.1.rand.s2q.AV.mc.35 10 10 100.0
# 6118002520 bpop.num_0..9.by.1.rand.x2s.Ax.rise.42__it_2 10 10 100.0
# [[6118002520, 'bpop.mn_0..9.MN-SD-UP-OFF1-BL2.incr.3', 84, 134, 62.6865671641791], [6118002520, 'bpop.mn_0..9.MN-SD-UP-OFF1-BL1.incr.4', 219, 379, 57.78364116094987], [6118002520, 'bpop.mn_0..9.MN-SD-UP-OFF1-BL3.incr.2', 120, 174, 68.96551724137932], [6118002520, 'bpop.mn_0..9.MN-SD-UP-OFF2-BL3.incr.6', 20, 31, 64.51612903225806], [6118002520, 'bpop.mn_4..9.MN-SD-UP-OFF1-BL4.decr.17', 36, 57, 63.1578947368421], [6118002520, 'bpop.gl_dot.0..9.GL_SD_OFF1_L.bub2.6', 15, 21, 71.42857142857143], [6118002520, 'bpop.gl_dot.0..9.GL_SD_OFFW1_L.bub2.8', 10, 14, 71.42857142857143], [6118002520, 'bpop.gl_num.0..9.GL_SD_OFF1_M.bub3.13', 20, 43, 46.51162790697674], [6118002520, 'bpop.mn_4..9.MN-SD-UP-OFF1-BL1.decr.20', 32, 53, 60.37735849056604], [6118002520, 'bpop.mn_4..9.MN-SD-UP-OFF1-BL2.decr.19', 10, 15, 66.66666666666667], [6118002520, 'bpop.mn_4..9.MN-SD-UP-OFF1-BL3.decr.18', 51, 75, 68.0], [6118002520, 'bpop.gl_num.0..9.GL_SD_OFFW1_M.bub3.15', 40, 61, 65.57377049180327], [6118002520, 'bpop.gl_num.0..9.GL_SD_OFFW1_L.bub3.16', 24, 37, 64.86486486486487], [6118002520, 'bpop.mn_0..9.MN-SD-UP-OFF1-BL4.incr.1', 58, 88, 65.9090909090909], [6118002520, 'bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2', 20, 22, 90.9090909090909], [6118002520, 'bpop.num_1..4.by.1.asc.q2q.AV.mc.1', 12, 15, 80.0], [6118002520, 'bpop.num_1..4.by.1.asc.q2q.AV.rise.2', 10, 11, 90.9090909090909], [6118002520, 'bpop.num_0..9.by.1.asc.q2q.AV.mc.11', 10, 10, 100.0], [6118002520, 'bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_1', 10, 11, 90.9090909090909], [6118002520, 'bpop.num_0..9.by.1.dn.q2q.AV.rise.22', 10, 11, 90.9090909090909], [6118002520, 'bpop.num_0..9.by.1.rand.q2q.AV.mc.31', 12, 14, 85.71428571428571], [6118002520, 'bpop.num_0..9.by.1.rand.q2q.AV.rise.32', 11, 16, 68.75], [6118002520, 'bpop.num_1..4.by.1.asc.s2s.AV.mc.7', 15, 19, 78.94736842105263], [6118002520, 'bpop.num_1..4.by.1.asc.s2s.AV.rise.8', 10, 11, 90.9090909090909], [6118002520, 'bpop.num_1..4.by.1.asc.x2s.Ax.mc.9', 10, 10, 100.0], [6118002520, 'bpop.num_0..9.by.1.asc.s2s.AV.mc.17', 10, 11, 90.9090909090909], [6118002520, 'bpop.num_0..9.by.1.asc.x2s.Ax.mc.19', 10, 11, 90.9090909090909], [6118002520, 'bpop.num_0..9.by.1.dn.s2s.AV.mc.27', 10, 10, 100.0], [6118002520, 'bpop.num_0..9.by.1.dn.x2s.Ax.mc.29', 20, 24, 83.33333333333333], [6118002520, 'bpop.num_0..9.by.1.dn.x2s.Ax.rise.30', 24, 33, 72.72727272727273], [6118002520, 'bpop.num_0..9.by.1.rand.s2s.AV.mc.37', 10, 10, 100.0], [6118002520, 'bpop.num_0..9.by.1.rand.s2s.AV.rise.38', 10, 12, 83.33333333333333], [6118002520, 'bpop.num_0..9.by.1.rand.x2s.Ax.mc.39', 10, 10, 100.0], [6118002520, 'bpop.num_0..9.by.1.rand.x2s.Ax.rise.42__it_1', 10, 13, 76.92307692307692], [6118002520, 'bpop.num_1..4.by.1.asc.q2s.AV.rise.4', 15, 22, 68.18181818181819], [6118002520, 'bpop.num_0..9.by.1.asc.q2s.AV.mc.13', 10, 10, 100.0], [6118002520, 'bpop.num_0..9.by.1.dn.q2s.AV.rise.24', 10, 10, 100.0], [6118002520, 'bpop.num_0..9.by.1.rand.q2s.AV.mc.33', 10, 10, 100.0], [6118002520, 'bpop.num_1..4.by.1.asc.s2q.AV.mc.5', 20, 21, 95.23809523809524], [6118002520, 'bpop.num_0..9.by.1.asc.s2q.AV.rise.16', 10, 12, 83.33333333333333], [6118002520, 'bpop.num_0..9.by.1.dn.s2q.AV.mc.25', 10, 12, 83.33333333333333], [6118002520, 'bpop.num_0..9.by.1.dn.s2q.AV.rise.26', 19, 30, 63.333333333333336], [6118002520, 'bpop.num_0..9.by.1.rand.s2q.AV.mc.35', 10, 10, 100.0], [6118002520, 'bpop.num_0..9.by.1.rand.x2s.Ax.rise.42__it_2', 10, 10, 100.0]]
# Types of tutor levels assoc. with this student 6118003400 :  1
# 6118003400 bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2 5 21 23.80952380952381
# [[6118003400, 'bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2', 5, 21, 23.80952380952381]]
# Types of tutor levels assoc. with this student 6118003535 :  7
# 6118003535 bpop.mn_0..9.MN-SD-UP-OFF1-BL4.incr.1 10 10 100.0
# 6118003535 bpop.mn_0..9.MN-SD-UP-OFF1-BL2.incr.3 1 1 100.0
# 6118003535 bpop.mn_0..9.MN-SD-UP-OFF1-BL3.incr.2 10 11 90.9090909090909
# 6118003535 bpop.mn_0..9.MN-SD-UP-OFF1-BL1.incr.4 20 31 64.51612903225806
# 6118003535 bpop.mn_4..9.MN-SD-UP-OFF1-BL4.decr.17 9 15 60.0
# 6118003535 bpop.mn_4..9.MN-SD-UP-OFF1-BL3.decr.18 35 50 70.0
# 6118003535 bpop.mn_4..9.MN-SD-UP-OFF1-BL2.decr.19 11 17 64.70588235294117
# [[6118003535, 'bpop.mn_0..9.MN-SD-UP-OFF1-BL4.incr.1', 10, 10, 100.0], [6118003535, 'bpop.mn_0..9.MN-SD-UP-OFF1-BL2.incr.3', 1, 1, 100.0], [6118003535, 'bpop.mn_0..9.MN-SD-UP-OFF1-BL3.incr.2', 10, 11, 90.9090909090909], [6118003535, 'bpop.mn_0..9.MN-SD-UP-OFF1-BL1.incr.4', 20, 31, 64.51612903225806], [6118003535, 'bpop.mn_4..9.MN-SD-UP-OFF1-BL4.decr.17', 9, 15, 60.0], [6118003535, 'bpop.mn_4..9.MN-SD-UP-OFF1-BL3.decr.18', 35, 50, 70.0], [6118003535, 'bpop.mn_4..9.MN-SD-UP-OFF1-BL2.decr.19', 11, 17, 64.70588235294117]]

# %%
map_student_to_perf = dict(key_value)

# %%
result_df = None

for student_id in bpop_math_students:
#     map_student_to_perf[student_id] is a pandas dataframe
    if result_df is None:
        result_df = map_student_to_perf[student_id]
    else:
        result_df = result_df.append(map_student_to_perf[student_id], ignore_index=True)
    
result_df
# Out:
#     Anon Student Id                                Level (Tutor)  # Correct  \
# 0        5A22000679  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2          2
# 1        5A27002160     bpop.mn_40..99.MN-DD-UP-OFF5-BL4.decr.57         65
# 2        5A27002160     bpop.mn_10..99.MN-DD-UP-OFF5-BL2.incr.43         83
# 3        5A27002160    bpop.mn_10..99.MN-DD-UP-OFF10-BL4.incr.45         10
# 4        5A27002160     bpop.mn_40..99.MN-DD-UP-OFF5-BL3.decr.58          5
# ..              ...                                          ...        ...
# 172      6118003535        bpop.mn_0..9.MN-SD-UP-OFF1-BL3.incr.2         10
# 173      6118003535        bpop.mn_0..9.MN-SD-UP-OFF1-BL1.incr.4         20
# 174      6118003535       bpop.mn_4..9.MN-SD-UP-OFF1-BL4.decr.17          9
# 175      6118003535       bpop.mn_4..9.MN-SD-UP-OFF1-BL3.decr.18         35
# 176      6118003535       bpop.mn_4..9.MN-SD-UP-OFF1-BL2.decr.19         11
#
#      # attempted  % correct
# 0              7  28.571429
# 1             76  85.526316
# 2            110  75.454545
# 3             14  71.428571
# 4             12  41.666667
# ..           ...        ...
# 172           11  90.909091
# 173           31  64.516129
# 174           15  60.000000
# 175           50  70.000000
# 176           17  64.705882
#
# [177 rows x 5 columns]

# %%
# create excel writer object
writer = pd.ExcelWriter('output.xlsx')
# write dataframe to excel
result_df.to_excel(writer)
# save the excel
writer.save()
