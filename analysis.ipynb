# %%
import pandas as pd
import os

# %%
# os.chdir('Data')
# !ls
# Out:
# Transactions_Village114

# %%
# !ls
path = 'Transactions_Village114/ds3170_tx_All_Data_5208_2019_1211_082948.txt'
df = pd.read_csv(path, sep="\t")
cols = ['Anon Student Id', 
        'Session Id', 
        'Duration (sec)', 
        'Level (Tutor Name)', 
        'Level (Tutor)', 
        'Problem Name', 
        'Problem View',
        'Step Name', 
        'Attempt At Step',
        'Is Last Attempt',
        'Outcome', 
        'Input',
        'CF (File)',
        'CF (Matrix)',
        'CF (Matrix Level)', 
        'CF (Matrix Order)', 
        'CF (Total Activity Problems)'
       ]
df = df[cols]
df
# Out:
# Transactions_Village114
#        Anon Student Id                         Session Id Duration (sec)  \
# 0           5A22000679         5A22000679_20180605_154801              0
# 1           5A22000679         5A22000679_20180605_154801              .
# 2           5A22000679         5A22000679_20180605_154801            122
# 3           5A22000679         5A22000679_20180605_154801             66
# 4           5A22000679         5A22000679_20180605_154801             97
# ...                ...                                ...            ...
# 166942      6118003535  6118003535_000081_20000114_024944             33
# 166943      6118003535  6118003535_000081_20000114_024944             13
# 166944      6118003535  6118003535_000081_20000114_024944             11
# 166945      6118003535  6118003535_000081_20000114_024944             14
# 166946      6118003535  6118003535_000081_20000114_024944             16
#
#        Level (Tutor Name)                                Level (Tutor)  \
# 0              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 1              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 2              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 3              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# 4              bubble_pop  bpop.num_0..9.by.1.asc.q2q.AV.rise.12__it_2
# ...                   ...                                          ...
# 166942          word_copy                 write.ltr.lc_all.asc.A..Z.11
# 166943          word_copy                 write.ltr.lc_all.asc.A..Z.11
# 166944          word_copy                 write.ltr.lc_all.asc.A..Z.11
# 166945          word_copy                 write.ltr.lc_all.asc.A..Z.11
# 166946          word_copy                 write.ltr.lc_all.asc.A..Z.11
#
#         Problem Name  Problem View  Step Name  Attempt At Step  \
# 0       BPOP_0_1-0-5           1.0          1                1
# 1       BPOP_0_1-0-5           1.0          1                2
# 2       BPOP_1_2-8-1           1.0          1                1
# 3       BPOP_1_2-8-1           1.0          1                2
# 4       BPOP_1_2-8-1           1.0          1                3
# ...              ...           ...        ...              ...
# 166942       write_h           1.0          1                1
# 166943       write_i           1.0          1                1
# 166944       write_j           1.0          1                1
# 166945       write_j           1.0          1                2
# 166946       write_k           1.0          1                1
#
#         Is Last Attempt    Outcome Input  \
# 0                     0  INCORRECT     1
# 1                     1    CORRECT     0
# 2                     0  INCORRECT     8
# 3                     0  INCORRECT     2
# 4                     1  INCORRECT     8
# ...                 ...        ...   ...
# 166942                1    CORRECT     h
# 166943                1    CORRECT     i
# 166944                0  INCORRECT     j
# 166945                1    CORRECT     j
# 166946                1  INCORRECT     5
#
#                                                 CF (File) CF (Matrix)  \
# 0       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 1       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 2       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 3       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# 4       PERF_RoboTutor_release_sw.1.8.9.1_2018.06.05.1...        math
# ...                                                   ...         ...
# 166942  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
# 166943  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
# 166944  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
# 166945  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
# 166946  PERF_RoboTutor_release_sw_2.7.7.1_000081_2000....    literacy
#
#         CF (Matrix Level)  CF (Matrix Order)  CF (Total Activity Problems)
# 0                       1                 30                            10
# 1                       1                 30                            10
# 2                       1                 30                            10
# 3                       1                 30                            10
# 4                       1                 30                            10
# ...                   ...                ...                           ...
# 166942                  4                594                            24
# 166943                  4                594                            24
# 166944                  4                594                            24
# 166945                  4                594                            24
# 166946                  4                594                            24
#
# [166947 rows x 17 columns]

# %%
unique_student_ids = df['Anon Student Id'].unique()
no_of_students = len(unique_student_ids)
print(no_of_students)

unique_problem_names = df['Problem Name'].unique()
no_of_problem_names = len(unique_problem_names)
print(no_of_problem_names)

unique_tutor_names = df['Level (Tutor Name)'].unique()
no_of_tutor_names = len(unique_tutor_names)
print(unique_tutor_names)
print(no_of_tutor_names)
# Out:
# 16
# 8395
# ['bubble_pop' 'story_reading' 'akira' 'word_copy' 'story_questions'
#  'countingx' 'spelling' 'add_subtract' 'numdiscr' 'picmatch']
# 10

# %% [markdown]
# ## Activity-wise Analysis
# #### 'bubble_pop', 'story_reading', 'akira', 'word_copy', 'story_questions', 'countingx', 'spelling', 'add_subtract', 'numdiscr', 'picmatch'

# %%
# bubble_pop -> 23443
bubble_pop_df = df[df['Level (Tutor Name)'] == 'bubble_pop']
# bubble_pop_df

# %%
# story_reading -> 129383
story_reading_df = df[df['Level (Tutor Name)'] == 'story_reading']
# story_reading_df.count()

# %%
# akira -> 3840
akira_df = df[df['Level (Tutor Name)'] == 'akira']
# akira_df.count()

# %%
# word_copy -> 4245
word_copy_df = df[df['Level (Tutor Name)'] == 'word_copy']
# word_copy_df.count()

# %%
# story_questions -> 1142
story_questions_df = df[df['Level (Tutor Name)'] == 'story_questions']
# story_questions_df.count()

# %%
# countingx -> 471
countingx_df = df[df['Level (Tutor Name)'] == 'countingx']
# countingx_df.count()

# %%
# spelling -> 2627
spelling_df = df[df['Level (Tutor Name)'] == 'spelling']
# spelling_df.count()

# %%
# add_subtract -> 215
add_subtract_df = df[df['Level (Tutor Name)'] == 'add_subtract']
# add_subtract_df.count()

# %%
# numdiscr -> 970
numdiscr_df = df[df['Level (Tutor Name)'] == 'numdiscr']
# numdiscr_df.count()

# %%
# picmatch -> 611
picmatch_df = df[df['Level (Tutor Name)'] == 'picmatch']
# picmatch_df.count()
